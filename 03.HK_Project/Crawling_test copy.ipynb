# %% [markdown]
# ### BeautifulSoup 사용해서 저스트와치 상세페이지 포스터 이미지 다운로드

# %%
# csv파일 읽어오기
import pandas as pd
csv_test = pd.read_csv("C:/Users/Kims/Desktop/HK_Project_Team5/key_wavve.csv")
csv_test.head()
csv_test2 = csv_test.drop(["Unnamed: 0"], axis=1)
csv_test03 = csv_test2['~03']
csv_test03.values[0:10]
# Out:
# array(['banjiyi-jewang-banji-weonjeongdae', 'namsaegdaemun',
#        'meolholraendeu-deuraibeu',
#        'harry-potter-and-the-philosophers-stone', 'peolpeu-pigsyeon',
#        'infernal-affairs', 'yangdeulyi-cimmug', 'reobeu-reteo', 'top-gun',
#        'meet-joe-black'], dtype=object)

# %%
csv_wavve= csv_test.drop(["Unnamed: 0"], axis=1)
csv_wavve04_11 = csv_wavve['04~11']
csv_wavve04_11.values[132]
# Out:
# 'transformers'

# %% [markdown]
# ##### 세부정보는 통으로 크롤링이 가능하지만 DT로 분류시에 문제가 발생할 가능성이 있음

# %%
# 출연진 가져오기 - 배우명 가져오기
actors = soup.find("div", class_="hidden-horizontal-scrollbar__items")
actors = actors.find_all("a", class_="title-credit-name")
actors_list = []
for actor in actors:    
    actor = actor.get_text().strip()
    actors_list.append(actor)    
actors_list = ",".join(actors_list)
print(actors_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22656/2376056412.py in <module>
#       1 # 출연진 가져오기 - 배우명 가져오기
#       2 actors = soup.find("div", class_="hidden-horizontal-scrollbar__items")
# ----> 3 actors = actors.find_all("a", class_="title-credit-name")
#       4 actors_list = []
#       5 for actor in actors:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# 시놉시스 따오는거 테스트용
# 시놉시스 copy-selector 로 가져오기 
# 가장 마지막 부분의 있는 :nth-child()  부분은 지워주어야함
# 예시) #base > div.jw-info-box > div > div.jw-info-box__container-content > div:nth-child(2) > div:nth-child(6) > div:nth-child(1) > div:nth-child() <- 이곳 마지막부분을 지워야함 > p > span
target_url = "https://www.justwatch.com/kr/%EC%98%81%ED%99%94/harry-potter-and-the-philosophers-stone"
html = urllib.request.urlopen(target_url).read()
soup = BeautifulSoup(html, "html.parser")
synopsis = soup.select("#base > div.jw-info-box > div > div.jw-info-box__container-content > div:nth-child(2) > div > div > div > p > span")
print(synopsis[0].get_text())
# Out:
# 해리 포터는 위압적인 버논 숙부와 냉담한 이모 페투니아, 욕심 많고 버릇없는 사촌 더즐리 밑에서 갖은 구박을 견디며 계단 밑 벽장에서 생활한다. 이모네 식구들 역시 해리와의 동거가 불편하기는 마찬가지. 이모 페투니아에겐 해리가 이상한 언니 부부에 관한 기억을 떠올리게 만드는 달갑지 않은 존재다. 11살 생일이 며칠 앞으로 다가왔지만 한번도 생일파티를 치르거나 제대로 된 생일선물을 받아 본 적이 없는 해리로서는 특별히 신날 것도 기대 할 것도 없다. 11살 생일을 며칠 앞둔 어느 날 해리에게 초록색 잉크로 쓰여진 한 통의 편지가 배달된다. 그 편지의 내용은 다름 아닌 해리의 11살 생일을 맞이하여 호그와트에서 보낸 입학 초대장이었다. 그리고 해리의 생일을 축하하러 온 거인 해그리드는 해리가 모르고 있었던 해리의 진정한 정체를 알려주는데...

# %%
import urllib.request
from bs4 import BeautifulSoup
target_url = "https://www.justwatch.com/kr/%EC%98%81%ED%99%94/yeoyido"
html = urllib.request.urlopen(target_url).read()
soup = BeautifulSoup(html, "html.parser")
synopsis = soup.select("#base > div.jw-info-box > div > div.jw-info-box__container-content > div:nth-child(2) > div > div > div > p > span")[0].get_text()
#base > div.jw-info-box > div > div.jw-info-box__container-content > div:nth-child(2) > div:nth-child(6) > div:nth-child(1) > div > p > span
print(synopsis)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22656/1988667716.py in <module>
#       4 html = urllib.request.urlopen(target_url).read()
#       5 soup = BeautifulSoup(html, "html.parser")
# ----> 6 synopsis = soup.select("#base > div.jw-info-box > div > div.jw-info-box__container-content > div:nth-child(2) > div > div > div > p > span")[0].get_text()
#       7 #base > div.jw-info-box > div > div.jw-info-box__container-content > div:nth-child(2) > div:nth-child(6) > div:nth-child(1) > div > p > span
#       8 print(synopsis)
#
# IndexError: list index out of range

# %%
import urllib.request
from bs4 import BeautifulSoup
target_url = "https://www.justwatch.com/kr/%EC%98%81%ED%99%94/ratatouille"
html = urllib.request.urlopen(target_url).read()
soup = BeautifulSoup(html, "html.parser")
rate = soup.select_one("#base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div:nth-child(2)").text()
genre = soup.select_one("#base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div:nth-child(3)").text()
runtime = soup.select_one("#base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div:nth-child(4)").text()
director = soup.select_one("#base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div:nth-child(5)").text()
print(rate, genre, runtime,director)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13032/1775871349.py in <module>
#       4 html = urllib.request.urlopen(target_url).read()
#       5 soup = BeautifulSoup(html, "html.parser")
# ----> 6 rate = soup.select_one("#base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div:nth-child(2)").text()
#       7 genre = soup.select_one("#base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div:nth-child(3)").text()
#       8 runtime = soup.select_one("#base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div:nth-child(4)").text()
# ...

# %%
# 가져와야 할 detail_info 정보의 태그를 가져온다
import urllib.request
from bs4 import BeautifulSoup
target_url = "https://www.justwatch.com/kr/%EC%98%81%ED%99%94/ratatouille"
html = urllib.request.urlopen(target_url).read()
soup = BeautifulSoup(html, "html.parser")
#detail_info = soup.find("div", {"class": "title-info visible-xs visible-sm"})
detail_info = soup.find("div", class_="title-info visible-xs visible-sm")
# divs = detail_info.find_all("div")
# for div in divs:
div_2 = soup.find_all("div", class_="detail-infos")
rate = div_2[0].text.strip()
genre = div_2[1].text.strip()
runtime = div_2[2].text.strip()
director = div_2[3].text.strip()
print(rate, genre, runtime,director)
# Out:
# 평점 88%  8.1 (689k) 장르애니메이션 , 코미디 , 가족 , 판타지 , 드라마 재생 시간1시간 50분 감독 Brad Bird

# %%
# csv파일 읽어오기
import pandas as pd
csv_test = pd.read_csv("C:/Users/Kims/Desktop/HK_Project_Team5/key_wavve.csv")
csv_test.head()
csv_test2 = csv_test.drop(["Unnamed: 0"], axis=1)
csv_test03 = csv_test2['~03']
csv_test03.values[1890]
# Out:
# 'sangceo'

# %%
title_list =[]
openingdate_list = []
rate_list = []
genre_list = []
runtime_list = []
director_list = []
synopsis_list = []
ac_list = []

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import urllib.request



def get_soup(target_url):
    html = urllib.request.urlopen(target_url)
    soup = BeautifulSoup(html, "html.parser")
    return soup

def extract_data(soup):
    detail_info = soup.find("div", class_="title-info visible-xs visible-sm")
    detile_infos = soup.find_all("div", class_="detail-infos")
    rate = soup.select("base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div-child(2)")
    #rate = detile_infos[0].text.strip().replace("평점","")
    #base > div.jw-info-box > div > div.jw-info-box__container-sidebar > div > aside > div.hidden-sm.visible-md.visible-lg.title-sidebar__desktop > div.title-info > div:nth-child(3)
    #genre = detile_infos[1].text.strip().replace("장르","")
    runtime = detile_infos[2].text.strip().replace("재생 시간","")
    director = detile_infos[3].text.strip().replace("감독","")


    actors = soup.find("div", class_="hidden-horizontal-scrollbar__items")
    actors = actors.find_all("a", class_="title-credit-name")
    actors_list = []
    for actor in actors:
        actor = actor.get_text().strip()
        actors_list.append(actor)         # 함수 내에서 for 문으로 뽑아낸 값을 actor_list로 저장
    actors_list = ",".join(actors_list)   #여기까지 tpye은 스트링 출력

    title = soup.find("div", class_="title-block")
    title_kor = title.find("h1").get_text().strip()
    opening_data = title.find("span", class_="text-muted").get_text().strip()
    #synopsis = soup.select("#base > div.jw-info-box > div > div.jw-info-box__container-content > div:nth-child(2) > div > div > div > p > span")[0].text.strip()    
    try:
        synopsis = soup.select("#base > div.jw-info-box > div > div.jw-info-box__container-content > div:nth-child(2) > div > div > div > p > span")[0].text.strip()
    except:
        synopsis=None
    
    
    # if synopsis == None or synopsis == '':
    #     synopsis = None
    
   
    title_list.append(title_kor)
    openingdate_list.append(opening_data)
    rate_list.append(rate)
    genre_list.append(genre)
    runtime_list.append(runtime)
    director_list.append(director)
    synopsis_list.append(synopsis)
    ac_list.append(actors_list)                 # 위 for 문에서 뽑아낸 데이터 정보를 함수 밖의 ac_list로 저장
    
    print("=======================================================================================================================================")
    print(title_kor, opening_data, rate, genre, runtime, director)
    print(synopsis)
    print(actors_list)    # 함수값 안에서의 출연진 값이 print 값으로 표시됨


for i in csv_wavve04_11.values:
    target_url = "https://www.justwatch.com/kr/%EC%98%81%ED%99%94/{}".format(i)
    soup = get_soup(target_url)
    extract_data(soup)
# Out:
# ...
# 시간 여행자의 아내 (2009)  77%  7.1 (147k) 판타지 , 로맨스 , SF , 코미디 , 드라마 , Made in Europe 1시간 48분  Robert Schwentke
# “돌아갈게... 당신이 있는 시간으로”  나는 시간여행자다. 어릴 적 교통사고 때 시간이동을 경험한 이후 나의 의지와는 상관없이 시간 여행을 하게 되었다. 갑작스런 시간 이동 후엔 알몸으로 낯선 곳에 떨어지기 때문에 늘 추위에 떨거나, 옷을 훔쳐 경찰에 쫓겨야 하는 신세이다. 현재의 삶은 언제나 외롭다. 매일 혼자 맞는 아침이 익숙해져 갈 때쯤 그녀가 나타났다. 아침 햇살처럼 빛나는 그녀가...  “기다릴게… 당신이 올 때까지”  그를 처음 만난 날을 기억하고 있다. 여섯 살이던 해, 나만의 비밀 초원에 나타난 그는 자신을 시간여행자라고 소개했다. 그는 먼 훗날 우리가 친구가 될 거라 했다. 나는 매일매일 그가 찾아와주길 기다렸고, 나와 사랑에 빠지기를 기다렸다. 스무 살이 되던 해, 드디어 그를 다시 만났다. 나를 기억하지 못하는 스물 여덟 살의 그를...
# ...

# %%
df = pd.DataFrame({
    "제목":title_list,'개봉일':openingdate_list,'평점':rate_list, '장르':genre_list, '재생시간':runtime_list, '감독':director_list,"출연진":ac_list, "시놉시스":synopsis_list})
df.tail(5)
# Out:
#                     제목     개봉일                평점             장르     재생시간  \
# 218  미션 임파서블: 고스트 프로토콜  (2011)   80%  7.4 (477k)       스릴러 , 액션  2시간 13분
# 219           핫 텁 타임머신  (2010)   69%  6.4 (170k)  코미디 , SF , 액션  1시간 37분
# 220            수상한 고객들  (2011)          71%  6.3      코미디 , 드라마   2시간 4분
# 221                 점퍼  (2008)   68%  6.1 (300k)  SF , 스릴러 , 액션  1시간 28분
# 222              행오버 2  (2011)   73%  6.5 (487k)            코미디  1시간 42분
#
#                  감독                                                출연진  \
# 218       Brad Bird  Tom Cruise,Paula Patton,Simon Pegg,Jeremy Renn...
# 219      Steve Pink  John Cusack,Rob Corddry,Craig Robinson,Clark D...
# 220      Cho Jin-mo  Ryoo Seung-bum,Sung Dong-il,Jung Sun-kyung,Seo...
# 221      Doug Liman  Hayden Christensen,Jamie Bell,Samuel L. Jackso...
# 222   Todd Phillips  Bradley Cooper,Ed Helms,Zach Galifianakis,Just...
#
#                                                   시놉시스
# ...

# %%
df.to_excel("test2003년.xlsx")
