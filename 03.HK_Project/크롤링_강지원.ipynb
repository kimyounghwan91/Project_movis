# %%
key_list = ["dyun", "ssing2gedeo", "murder-on-the-orient-express", "benom-2-res-deeo-bi-kaniji", 
"peurenci-diseupaeci", "gyeonggwanyi-pi", "deo-raseuteu-dyueol", "yeonae-bbajin-romaenseu"]
key_list
# Out:
# ['dyun',
#  'ssing2gedeo',
#  'murder-on-the-orient-express',
#  'benom-2-res-deeo-bi-kaniji',
#  'peurenci-diseupaeci',
#  'gyeonggwanyi-pi',
#  'deo-raseuteu-dyueol',
#  'yeonae-bbajin-romaenseu']

# %%
rate_list = []
genre_list = []
runtime_list = []
director_list = []

# %%
# 1900개 이상하면 중간에 멈춤, 처리할수있는 용량의 문제가 있는 것인가?
from urllib.request import urlopen
from bs4 import BeautifulSoup
import urllib.request

def get_soup(target_url):
    html = urllib.request.urlopen(target_url).read()
    soup = BeautifulSoup(html, "html.parser")
    return soup

def extract_data(soup):
    detail_info = soup.find("div", {"class": "title-info visible-xs visible-sm"})
    divs = detail_info.find_all("div")
    
    # for div in divs: #for 문을 돌아야 할 이유 없어보여.
    div_2 = soup.find_all("div", class_="detail-infos")
    rate = div_2[0].text.strip()
    genre = div_2[1].text.strip()
    runtime = div_2[2].text.strip()
    director = div_2[3].text.strip()
        # 추가
    rate_list.append(rate)
    genre_list.append(genre)
    runtime_list.append(runtime)
    director_list.append(director)

    print(rate, genre, runtime, director)

for i in key_list:
    target_url = "https://www.justwatch.com/kr/%EC%98%81%ED%99%94/{}".format(i)
    soup = get_soup(target_url)
    extract_data(soup)
# Out:
# 평점 90%  8.1 (496k) 장르SF , 드라마 , 액션 재생 시간2시간 35분 감독 Denis Villeneuve
# 평점 90%  7.5 (35k) 장르애니메이션 , 음악 , 코미디 , 가족 , 드라마 , 판타지 재생 시간1시간 52분 감독 Garth Jennings
# 평점 74%  6.5 (235k) 장르드라마 , 범죄 , 스릴러 재생 시간1시간 54분 감독 Kenneth Branagh
# 평점 77%  6.0 (177k) 장르SF , 액션 , 스릴러 , 코미디 , 공포 재생 시간1시간 37분 감독 Andy Serkis
# 평점 80%  7.2 장르드라마 , 로맨스 , 코미디 , 다큐멘터리 재생 시간1시간 47분 감독 Wes Anderson
# 평점 67%  6.0 장르스릴러 , 범죄 , 드라마 재생 시간1시간 59분 감독 Lee Kyu-man
# 평점 84%  7.4 (122k) 장르액션 , 드라마 , 역사 , 스릴러 재생 시간2시간 33분 감독 Ridley Scott
# 평점 67%  6.0 장르로맨스 , 코미디 , 드라마 재생 시간1시간 35분 감독 Jeong Ga-young

# %%
rate_list
# Out:
# ['평점 90%  8.1 (496k)',
#  '평점 90%  7.5 (35k)',
#  '평점 74%  6.5 (235k)',
#  '평점 77%  6.0 (177k)',
#  '평점 80%  7.2',
#  '평점 67%  6.0',
#  '평점 84%  7.4 (122k)',
#  '평점 67%  6.0']

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'key':key_list, '평점':rate_list, '장르':genre_list, '재생시간':runtime_list, '감독':director_list
})
df
# Out:
#                             key                  평점  \
# 0                          dyun  평점 90%  8.1 (496k)
# 1                   ssing2gedeo   평점 90%  7.5 (35k)
# 2  murder-on-the-orient-express  평점 74%  6.5 (235k)
# 3    benom-2-res-deeo-bi-kaniji  평점 77%  6.0 (177k)
# 4           peurenci-diseupaeci         평점 80%  7.2
# 5               gyeonggwanyi-pi         평점 67%  6.0
# 6           deo-raseuteu-dyueol  평점 84%  7.4 (122k)
# 7       yeonae-bbajin-romaenseu         평점 67%  6.0
#
#                                     장르          재생시간                   감독
# 0                      장르SF , 드라마 , 액션  재생 시간2시간 35분  감독 Denis Villeneuve
# 1  장르애니메이션 , 음악 , 코미디 , 가족 , 드라마 , 판타지  재생 시간1시간 52분    감독 Garth Jennings
# 2                     장르드라마 , 범죄 , 스릴러  재생 시간1시간 54분   감독 Kenneth Branagh
# 3           장르SF , 액션 , 스릴러 , 코미디 , 공포  재생 시간1시간 37분       감독 Andy Serkis
# 4            장르드라마 , 로맨스 , 코미디 , 다큐멘터리  재생 시간1시간 47분      감독 Wes Anderson
# 5                     장르스릴러 , 범죄 , 드라마  재생 시간1시간 59분       감독 Lee Kyu-man
# 6                장르액션 , 드라마 , 역사 , 스릴러  재생 시간2시간 33분      감독 Ridley Scott
# 7                    장르로맨스 , 코미디 , 드라마  재생 시간1시간 35분    감독 Jeong Ga-young

# %%
soup
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22ko%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="ko"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta charset="utf-8" data-vue-meta="ssr"/><meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/><meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/><meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/><meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/><meta content="yes" data-vue-meta="ssr" name="mobile-web-app-capable"/><meta content="yes" data-vue-meta="ssr" name="apple-mobile-web-app-capable"/><meta content="#182531" data-vue-meta="ssr" name="theme-color"/><meta content="4eBTNBm4L6RaWdF8V51EHZajskAMgXYAg81iRXJqumQ" data-vue-meta="ssr" name="google-site-verification"/><meta content="d61y4roe8t5xwbb0gfu6gwe8j8iq3i" data-vue-meta="ssr" name="facebook-domain-verification"/><meta content="연애 빠진 로맨스 영화 스트리밍으로 보기 " data-vue-meta="ssr" property="og:title"/><meta content="연애 빠진 로맨스, 2021, 영화 스트리밍으로 볼 수 있는 곳" data-vue-meta="ssr" name="keywords"/><meta content="연애 빠진 로맨스 영화를 볼 때 넷플릭스, 왓챠플레이, pooq, N스토어 등 다양한 동영상 서비스들 중 어떤 것이 좋을까요? 온라인으로 볼 수 있는 사이트를 지금 바로 찾아보세요!" data-vue-meta="ssr" name="description"/><meta content="연애 빠진 로맨스 영화를 볼 때 넷플릭스, 왓챠플레이, pooq, N스토어 등 다양한 동영상 서비스들 중 어떤 것이 좋을까요? 온라인으로 볼 수 있는 사이트를 지금 바로 찾아보세요!" data-vue-meta="ssr" property="og:description"/><meta content="https://images.justwatch.com/poster/255380438/s718" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/><meta content="718" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/><meta content="1024" data-vmid="og:image:height" data-vue-meta="ssr" property="og:image:height"/><title>연애 빠진 로맨스 영화 스트리밍으로 보기 </title><link data-vue-meta="ssr" href="/kr/영화/yeonae-bbajin-romaenseu" hreflang="ko-KR" rel="alternate"/><link data-vue-meta="ssr" href="/tw/電影/pei-dui-you-xi" hreflang="zh-TW" rel="alternate"/><link data-vue-meta="ssr" href="/kr/영화/yeonae-bbajin-romaenseu" rel="canonical"/><link data-vue-meta="ssr" href="https://app.usercentrics.eu" rel="dns-prefetch"/><link data-vue-meta="ssr" href="https://graphql.usercentrics.eu" rel="dns-prefetch"/><link data-vue-meta="ssr" href="https://api.usercentrics.eu" rel="dns-prefetch"/><link data-vue-meta="ssr" href="https://consents.usercentrics.eu" rel="dns-prefetch"/><link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="true" data-vue-meta="ssr" href="/appassets/fonts/lato-700.woff2" rel="preload" type="font/woff2"/><link data-vue-meta="ssr" href="/appassets/favicon.ico" rel="icon"/><link crossorigin="use-credentials" data-vue-meta="ssr" href="https://images.justwatch.com" rel="preconnect"/><link data-vue-meta="ssr" href="https://www.googletagmanager.com/" rel="dns-prefetch"/><link data-vue-meta="ssr" href="https://ib.adnxs.com" rel="dns-prefetch"/><script data-vue-meta="ssr" type="application/ld+json">{"@graph":[{"@context":"http://schema.org","@type":"Movie","actor":[{"@type":"PerformanceRole","actor":{"@type":"Person","name":"Jeon Jong-seo"},"characterName":"Ja-young"},{"@type":"PerformanceRole","actor":{"@type":"Person","name":"Son Suk-ku"},"characterName":"Woo-ri"},{"@type":"PerformanceRole","actor":{"@type":"Person","name":"Gong Min-jeung"},"characterName":"Sun-bin"},{"@type":"PerformanceRole","actor":{"@type":"Person","name":"Kim Seul-gi"},"characterName":"Yu-mi"},{"@type":"Person","name":"Bae Yoo-ram"},{"@type":"Person","name":"Kim Jae-hwa"},{"@type":"Person","name":"Im Sung-jae"},{"@type":"Person","name":"Kim Young-ok"},{"@type":"Person","name":"Kim Kwang-kyu"},{"@type":"PerformanceRole","actor":{"@type":"Person","name":"Lee Hak-joo"},"characterName":"Min-seok"}],"author":[{"@type" ...
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  *//*! Source: https://github.com/h5bp/html5-boilerplate/blob/master/src/css/main.css */@media print{*,:after,:before{background:transparent!important;color:#000!important;box-shadow:none!important;text-shadow:none!important}a,a:visited{text-decoration:underline}a[href]:after{content:" (" attr(href) ")"}abbr[title]:after{content:" (" attr(title) ")"}a[href^="#"]:after,a[href^="javascript:"]:after{content:""}blockquote,pre{border:1px solid #999;page-break-inside:avoid}thead{display:table-header-group}img,tr{page-break-inside:avoid}img{max-width:100%!important}h2,h3,p{orphans:3;widows:3}h2,h3{page-break-after:avoid}.navbar{display:none}.btn>.caret,.dropup>.btn>.caret{border-top-color:#000!important}.label{border:1px solid #000}.table{border-collapse:collapse!important}.table td,.table th{background-color:#fff!important}.table-bordered td,.table-bordered th{border:1px solid #ddd!important}}*,:after,:before{box-sizing:border-box}html{font-size:10px;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{font-family:Lato,Lato-fallback,Arial,sans-serif;font-size:14px;line-height:1.428571429;color:#333;background-color:#fff}button,input,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#428bca}a,a:focus,a:hover{text-decoration:none}a:focus,a:hover{color:#2a6496}a:focus{outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}figure{margin:0}img{vertical-align:middle}.img-responsive{display:block;max-width:100%;height:auto}.img-rounded{border-radius:6px}.img-thumbnail{padding:4px;line-height:1.428571429;background-color:#fff;border:1px solid #ddd;border-radius:4px;transition:all .2s ease-in-out;display:inline-block;max-width:100%;height:auto}.img-circle{border-radius:50%}hr{margin-top:20px;margin-bottom:20px;border:0;border-top:1px solid #eee}.sr-only{position:absolute;width:1px;height:1px;margin:-1px;padding:0;overflow:hidden;clip:rect(0,0,0,0);border:0}.sr-only-focusable:active,.sr-only-focusable:focus{position:static;width:auto;height:auto;margin:0;overflow:visible;clip:auto}[role=button]{cursor:pointer}.container{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}.container:after,.container:before{content:" ";display:table}.container:after{clear:both}@media(min-width:768px){.container{width:750px}}@media(min-width:992px){.container{width:970px}}@media(min-width:1200px){.container{width:1170px}}.container-fluid{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}.container-fluid:after,.container-fluid:before{content:" ";display:table}.container-fluid:after{clear:both}.row{margin-left:-15px;margin-right:-15px}.row:after,.row:before{content:" ";display:table}.row:after{clear:both}.col-lg-1,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-lg-10,.col-lg-11,.col-lg-12,.col-md-1,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-10,.col-md-11,.col-md-12,.col-sm-1,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-sm-10,.col-sm-11,.col-sm-12,.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{position:relative;min-height:1px;padding-left:15px;padding-right:15px}.col-xs-1,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.col-xs-10,.col-xs-11,.col-xs-12{float:left}.col-xs-1{width:8.3333333333%}.col-xs-2{width:16.6666666667%}.col-xs-3{width:25%}.col-xs-4{width:33.3333333333%}.col-xs-5{width:41.6666666667%}.col-xs-6{width:50%}.col-xs-7{width:58.3333333333%}.col-xs-8{width:66.6666666667%}.col-xs-9{width:75%}.col-xs-10{width:83.3333333333%}.col-xs-11{width:91.6666666667%}.col-xs-12{width:100%}.col-xs-pull-0{right:auto}.col-xs-pull-1{right:8.3333333333%}.col-xs-pull-2{right:16.6666666667%}.col-xs-pull-3{right:25%}.col-xs-pull-4{right:33.3333333333%}.col-xs-pull-5{right:41.6666666667%}.col-xs-pull-6{right:50%}.col-xs-pull-7{right:58.3333333333%}.col-xs-pull-8{right:66.66666 ...
# .vue-recycle-scroller{position:relative}.vue-recycle-scroller.direction-vertical:not(.page-mode){overflow-y:auto}.vue-recycle-scroller.direction-horizontal:not(.page-mode){overflow-x:auto}.vue-recycle-scroller.direction-horizontal{display:-webkit-box;display:-ms-flexbox;display:flex}.vue-recycle-scroller__slot{-webkit-box-flex:1;-ms-flex:auto 0 0px;flex:auto 0 0}.vue-recycle-scroller__item-wrapper{-webkit-box-flex:1;-ms-flex:1;flex:1;-webkit-box-sizing:border-box;box-sizing:border-box;overflow:hidden;position:relative}.vue-recycle-scroller.ready .vue-recycle-scroller__item-view{position:absolute;top:0;left:0;will-change:transform}.vue-recycle-scroller.direction-vertical .vue-recycle-scroller__item-wrapper{width:100%}.vue-recycle-scroller.direction-horizontal .vue-recycle-scroller__item-wrapper{height:100%}.vue-recycle-scroller.ready.direction-vertical .vue-recycle-scroller__item-view{width:100%}.vue-recycle-scroller.ready.direction-horizontal .vue-recycle-scroller__item-view{height:100%}.resize-observer[data-v-b329ee4c]{border:none;background-color:transparent;opacity:0}.resize-observer[data-v-b329ee4c],.resize-observer[data-v-b329ee4c] object{position:absolute;top:0;left:0;z-index:-1;width:100%;height:100%;pointer-events:none;display:block;overflow:hidden}
# .svg-inline--fa,svg:not(:root).svg-inline--fa{overflow:visible}.svg-inline--fa{display:inline-block;font-size:inherit;height:1em;vertical-align:-.125em}.svg-inline--fa.fa-lg{vertical-align:-.225em}.svg-inline--fa.fa-w-1{width:.0625em}.svg-inline--fa.fa-w-2{width:.125em}.svg-inline--fa.fa-w-3{width:.1875em}.svg-inline--fa.fa-w-4{width:.25em}.svg-inline--fa.fa-w-5{width:.3125em}.svg-inline--fa.fa-w-6{width:.375em}.svg-inline--fa.fa-w-7{width:.4375em}.svg-inline--fa.fa-w-8{width:.5em}.svg-inline--fa.fa-w-9{width:.5625em}.svg-inline--fa.fa-w-10{width:.625em}.svg-inline--fa.fa-w-11{width:.6875em}.svg-inline--fa.fa-w-12{width:.75em}.svg-inline--fa.fa-w-13{width:.8125em}.svg-inline--fa.fa-w-14{width:.875em}.svg-inline--fa.fa-w-15{width:.9375em}.svg-inline--fa.fa-w-16{width:1em}.svg-inline--fa.fa-w-17{width:1.0625em}.svg-inline--fa.fa-w-18{width:1.125em}.svg-inline--fa.fa-w-19{width:1.1875em}.svg-inline--fa.fa-w-20{width:1.25em}.svg-inline--fa.fa-pull-left{margin-right:.3em;width:auto}.svg-inline--fa.fa-pull-right{margin-left:.3em;width:auto}.svg-inline--fa.fa-border{height:1.5em}.svg-inline--fa.fa-li{width:2em}.svg-inline--fa.fa-fw{width:1.25em}.fa-layers svg.svg-inline--fa{bottom:0;left:0;margin:auto;position:absolute;right:0;top:0}.fa-layers{display:inline-block;height:1em;position:relative;text-align:center;vertical-align:-.125em;width:1em}.fa-layers svg.svg-inline--fa{transform-origin:center center}.fa-layers-counter,.fa-layers-text{display:inline-block;position:absolute;text-align:center}.fa-layers-text{left:50%;top:50%;transform:translate(-50%,-50%);transform-origin:center center}.fa-layers-counter{background-color:#ff253a;border-radius:1em;box-sizing:border-box;color:#fff;height:1.5em;line-height:1;max-width:5em;min-width:1.5em;overflow:hidden;padding:.25em;right:0;text-overflow:ellipsis;top:0;transform:scale(.25);transform-origin:top right}.fa-layers-bottom-right{bottom:0;right:0;top:auto;transform:scale(.25);transform-origin:bottom right}.fa-layers-bottom-left{bottom:0;left:0;right:auto;top:auto;transform:scale(.25);transform-origin:bottom left}.fa-layers-top-right{right:0;top:0;transform:scale(.25);transform-origin:top right}.fa-layers-top-left{left:0;right:auto;top:0;transform:scale(.25);transform-origin:top left}.fa-lg{font-size:1.33333em;line-height:.75em;vertical-align:-.0667em}.fa-xs{font-size:.75em}.fa-sm{font-size:.875em}.fa-1x{font-size:1em}.fa-2x{font-size:2em}.fa-3x{font-size:3em}.fa-4x{font-size:4em}.fa-5x{font-size:5em}.fa-6x{font-size:6em}.fa-7x{font-size:7em}.fa-8x{font-size:8em}.fa-9x{font-size:9em}.fa-10x{font-size:10em}.fa-fw{text-align:center;width:1.25em}.fa-ul{list-style-type:none;margin-left:2.5em;padding-left:0}.fa-ul>li{position:relative}.fa-li{left:-2em;position:absolute;text-align:center;width:2em;line-height:inherit}.fa-border{border:.08em solid #eee;border-radius:.1em;padding:.2em .25em .15em}.fa-pull-left{float:left}.fa-pull-right{float:right}.fa.fa-pull-left,.fab.fa-pull-left,.fal.fa-pull-left,.far.fa-pull-left,.fas.fa-pull-left{margin-right:.3em}.fa.fa-pull-right,.fab.fa-pull-right,.fal.fa-pull-right,.far.fa-pull-right,.fas.fa-pull-right{margin-left:.3em}.fa-spin{animation:fa-spin 2s linear infinite}.fa-pulse{animation:fa-spin 1s steps(8) infinite}@keyframes fa-spin{0%{transform:rotate(0deg)}to{transform:rotate(1turn)}}.fa-rotate-90{-ms-filter:"progid:DXImageTransform.Microsoft.BasicImage(rotation=1)";transform:rotate(90deg)}.fa-rotate-180{-ms-filter:"progid:DXImageTransform.Microsoft.BasicImage(rotation=2)";transform:rotate(180deg)}.fa-rotate-270{-ms-filter:"progid:DXImageTransform.Microsoft.BasicImage(rotation=3)";transform:rotate(270deg)}.fa-flip-horizontal{-ms-filter:"progid:DXImageTransform.Microsoft.BasicImage(rotation=0, mirror=1)";transform:scaleX(-1)}.fa-flip-vertical{transform:scaleY(-1)}.fa-flip-both,.fa-flip-horizontal.fa-flip-vertical,.fa-flip-vertical{-ms-filter:"progid:DXImageTransform.Microsoft.BasicImage(rotation=2, mirror=1)"}.fa-flip-both,.fa-flip-horizontal.fa-flip-vertical{ ...
# #app{position:relative;z-index:0}body{overflow-x:hidden}ion-menu ion-content ion-toolbar,ion-popover ion-toolbar{--background:transparent!important}
# .search-overlay{position:fixed;display:block;width:100vw;height:100vh;top:0;left:0;right:0;bottom:0;background-color:rgba(0,0,0,.5);cursor:pointer}.navbar{position:-webkit-sticky;position:sticky;display:flex;background:#060d17;height:56px;width:100%;top:0;margin:0 auto;z-index:100}@media(max-width:1050px){.navbar{max-height:105px}}.navbar.remove-blur{-webkit-backdrop-filter:none;backdrop-filter:none}.navbar__wrapper{display:flex;justify-content:flex-end;width:100%;align-items:center;overflow:visible}@media(max-width:1050px){.navbar__wrapper{justify-content:center}}.navbar.navbar-hide{display:none!important}.navbar.landing-page{background:rgba(0,0,0,.35)}@media(min-width:1051px){.navbar.landing-page{height:86px;padding-top:15px;margin-bottom:-86px}.navbar.landing-page .navbar__logo img{width:219px}}@media(max-width:1050px){.navbar.landing-page{margin-bottom:0}}.navbar--hidden,.navbar.landing-page .landing-hide{display:none}.navbar--absolute{position:absolute}@media(max-width:1050px){.navbar{height:105px;align-items:flex-end}}@media(max-width:1050px){.navbar.navbar__button--watchlist a{color:var(--ion-color-primary)!important}}.navbar__logo{-webkit-padding-end:15px;padding-inline-end:15px;display:flex;align-items:center;flex-shrink:0}.navbar__logo img{width:131px}@media(max-width:1050px){.navbar__logo{position:absolute;top:0;width:100%;min-height:46px;display:flex;justify-content:center;align-items:center;margin:0;-webkit-padding-end:0;padding-inline-end:0}}.navbar--is-mobile .navbar__logo{justify-content:left}.navbar--is-ios .navbar__logo{height:56px}.navbar__logo-link{display:flex;align-items:center}.navbar.container .navbar__logo{-webkit-margin-start:0;margin-inline-start:0;-webkit-padding-start:0;padding-inline-start:0}.navbar__search{z-index:1;flex-grow:2;height:52px;margin:0 1em;display:flex}.navbar__search .search-suggester .searchbar-input{color:#fff;box-shadow:none;border-radius:4px;font-size:15px;padding:4px 0;-webkit-padding-start:50px;padding-inline-start:50px;-webkit-padding-end:15px;padding-inline-end:15px}@media(max-width:992px){.navbar__search--expanded{left:0;right:0;position:absolute}}.navbar.landing-page .navbar__search{flex-grow:0;width:25em;transition:width .6s;transition-delay:.1s;align-items:center;display:flex}.navbar.landing-page .navbar__search:focus-within{width:100%}@media(max-width:1050px){.navbar.landing-page .navbar__search:focus-within{display:flex;align-items:center;justify-content:space-around}}.navbar__extra{display:flex;min-width:92px}@media(max-width:1050px){.navbar__extra{display:none}}.navbar__extra__small{display:none}@media(max-width:1050px){.navbar__extra__small{display:block;position:absolute;top:0;width:100%}[dir=ltr] .navbar__extra__small{right:0}[dir=rtl] .navbar__extra__small{left:0}.navbar__extra__small--left{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--left{left:4px}[dir=rtl] .navbar__extra__small--left{right:4px}.navbar__extra__small--right{display:flex;position:absolute}[dir=ltr] .navbar__extra__small--right{right:0}[dir=rtl] .navbar__extra__small--right{left:0}}.navbar__extra--remove-spacing{min-width:unset}.navbar__button{height:56px;flex-grow:inherit;cursor:pointer}.navbar__button a{padding:0}.navbar__button>div,.navbar__button__link{justify-content:center}.navbar__button__link{display:flex;align-items:center;height:100%;white-space:nowrap;font-size:14px;color:#999c9f}.navbar__button__link.nav-link-active,.navbar__button__link.router-link-exact-active{font-weight:700;color:#d9e8ed!important}.navbar__button__link__item{margin:0 15px;display:flex}.navbar__button--watchlist .navbar__button__link__item{-webkit-margin-end:0;margin-inline-end:0}@media(max-width:1050px){.navbar__button--watchlist .navbar__button__link__item{display:none}}.navbar__button__icon{display:block}@media(min-width:1050px){.navbar__button__icon{margin:0 5px}}.navbar__button__icon.bookmark{display:none}@media(max-width:1050px){.navbar__button__icon.bookmark{display:block}}@media(max-width:1 ...
# .search-suggester{position:relative}.search-suggester input[type=search]::-webkit-search-cancel-button{display:none}.search-suggester__results{z-index:200;padding:0 8px 8px;margin:-9px 0 0}.search-suggester__results--mobile{padding:0;margin:-11px -1em -.4em}.search-suggester--web{text-align:start;width:100%;padding:0;height:52px;z-index:10}.search-suggester--web ion-searchbar.ios{--background:#10161d;padding:8px;height:52px}.search-suggester--web .searchbar-cancel-button.sc-ion-searchbar-ios{background:#10161d;-webkit-padding-end:8px;padding-inline-end:8px}.search-suggester__searchbar--mobile{padding-top:3px!important;padding-bottom:10px!important}.search-suggester__searchbar--mobile.md{height:52px;--background:#fff;--color:var(--ion-color-tertiary-shade)!important}.search-suggester__searchbar--mobile.md .searchbar-input{border-radius:4px!important}.search-suggester__searchbar input::-webkit-search-cancel-button{-webkit-appearance:none}.search-suggester__searchbar .searchbar-clear-icon{color:var(--ion-color-secondary)!important}.search-suggester__blocking{position:absolute;width:100%;padding:8px}.search-suggester__blocking__input{width:100%;height:38px;display:flex;align-items:center;background-color:var(--ion-color-tertiary-shade)}.searchbar-clear-button.sc-ion-searchbar-md{color:#fff!important}
# .logged-in[data-v-7fdc0144]{padding:0 15px;font-size:16px;color:var(--ion-color-primary);font-size:18px}.logged-in[data-v-7fdc0144],.not-logged-in[data-v-7fdc0144]{height:100%;display:flex;align-items:center}@media(max-width:1050px){.not-logged-in__button[data-v-7fdc0144]{display:none}}.not-logged-in__icon[data-v-7fdc0144]{display:none;font-size:16px;cursor:pointer}@media(max-width:1050px){.not-logged-in__icon[data-v-7fdc0144]{display:block}}@media(max-width:1050px){.not-logged-in[data-v-7fdc0144]{padding:0 15px}}
# .basic-button{background:none;border:none;margin:0;padding:0;outline:none;white-space:nowrap;cursor:pointer}.basic-button__content{overflow:hidden;text-overflow:ellipsis}.basic-button.sm{font-size:13px;padding:.4rem 1.35rem}.basic-button.md{padding:.75rem 1.5rem}.basic-button.lg{font-size:18px;padding:1.6rem 4rem}.basic-button.lg.rounded{border-radius:8px}.basic-button.w-full{width:100%}.basic-button.rounded{border-radius:4px}.basic-button.uppercase{text-transform:uppercase}.basic-button.primary{font-weight:700;background-color:#fbc500;color:#000}.basic-button.primary.bg-none{color:#fbc500}.basic-button.primary.bg-none:hover{background-color:rgba(251,197,0,.1)}.basic-button.primary.border{color:#fbcb1a;border:1px solid #fbcb1a}.basic-button.primary.border:hover{background-color:rgba(251,197,0,.1)}.basic-button.secondary{color:#fff;font-weight:700;background-color:#4c5a67}.basic-button.secondary.bg-none{color:#4c5a67}.basic-button.secondary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary.border{border:1px solid #5e6b76}.basic-button.secondary.border:hover{background-color:rgba(94,107,118,.1)}.basic-button.secondary:hover{background-color:#ddad00}.basic-button.tertiary{color:#fff;background-color:#1c252f}.basic-button.tertiary.bg-none{color:#1c252f}.basic-button.tertiary.bg-none:hover{background-color:rgba(94,107,118,.1)}.basic-button.tertiary.border{border:1px solid #383d47}.basic-button.tertiary.border:hover{background-color:rgba(56,61,71,.1)}.basic-button.tertiary:hover{background-color:#383d47}.basic-button.light{color:#d9e8ed;background-color:#1c252f}.basic-button.light:hover{background-color:#383d47}.basic-button.medium{color:#fff;background-color:#8c8c8c}.basic-button.medium.border{color:#999c9f;border:1px solid #999c9f}.basic-button.medium.border:hover{background-color:rgba(153,156,159,.1)}.basic-button.medium:hover{background-color:#999c9f}.basic-button.bg-none{background:transparent}.basic-button.disabled{cursor:default;opacity:.5;pointer-events:none}
# .navbar__button__link[data-v-267b26fd]{background:none;border:none;outline:none;cursor:pointer}
# .text-wrap-pre-line[data-v-6e04ba78]{white-space:pre-wrap}.content[data-v-6e04ba78]{--padding-top:56px;overflow:hidden}@media(max-width:1050px){.content[data-v-6e04ba78]{--padding-top:105px}}.middle-buybox-container[data-v-6e04ba78]{display:flex;flex-wrap:wrap}.middle-buybox-container .middle-buybox[data-v-6e04ba78]{width:45%}@media(max-width:600px){.middle-buybox-container .middle-buybox[data-v-6e04ba78]{width:100%}}.middle-buybox-container .middle-buybox[data-v-6e04ba78]  .price-comparison__grid__row--bundle{display:flex}.middle-buybox-container .middle-buybox[data-v-6e04ba78]  .price-comparison__grid__row__title{display:none}@media(max-width:600px){.middle-buybox-container[data-v-6e04ba78]{flex-direction:column}}
# .content[data-v-d7672432]{min-height:100vh;display:flex;flex-direction:column;--padding-top:56px}@media(max-width:1050px){.content[data-v-d7672432]{--padding-top:105px}}
# .backdrops{width:100%;position:relative;z-index:0;height:46vw}@media(min-width:992px){.backdrops{height:450px}}@media(max-width:992px)and (min-width:768px){.backdrops{height:290px}}@media(max-width:768px)and (min-width:480px){.backdrops{height:240px}}.backdrops--trailer-playing{height:375px;height:360px}@media(max-width:480px){.backdrops--trailer-playing{height:210px}}@media(max-width:768px)and (min-width:480px){.backdrops--trailer-playing{height:360px}}.backdrops .backdrop-trailer{position:relative;overflow:hidden;margin:auto;height:100%}.backdrops .backdrop-trailer .jw-title-clip--backdrop{height:100%}@media(min-width:1170px){.backdrops .backdrop-trailer:after{display:block;position:absolute;top:0;content:"";width:100%;height:100%;background-image:linear-gradient(0deg,var(--ion-background-color),transparent 120px);z-index:1;pointer-events:none}[dir=ltr] .backdrops .backdrop-trailer:after{left:0}[dir=rtl] .backdrops .backdrop-trailer:after{right:0}}@media(min-width:1524px){.backdrops .backdrop-trailer:after{background-image:radial-gradient(circle farthest-side,transparent 65%,var(--ion-background-color)),linear-gradient(0deg,var(--ion-background-color),transparent 60px)}}#tyche_trendi_video_container.jw-no-consent{transform:translateY(-50px)}@media(max-width:768px){#tyche_trendi_video_container.jw-no-consent{transform:translateY(-100px)}}#tyche_trendi_video_container.jw-android-banner{transform:translateY(-80px)}
# .jw-title-clips>.row>[class*=col-]{margin-bottom:15px}
# .jw-title-clip{overflow:hidden;border-radius:5px;position:relative;max-height:360px}.jw-title-clip embed,.jw-title-clip iframe,.jw-title-clip img,.jw-title-clip object{width:100%}.jw-title-clip--backdrop{max-height:450px;border-radius:0}.jw-title-clip .trailer-backdrop{position:absolute;z-index:1;width:100%;opacity:.7;filter:blur(2px);transition:opacity .5s,filter .5s}.jw-title-clip .trailer-backdrop img{object-fit:cover;min-height:200px}.jw-title-clip .youtube-trailer-container{max-width:1120px;margin:0 auto;z-index:10;position:relative;padding-bottom:75px}@media(max-width:768px){.jw-title-clip .youtube-trailer-container{padding:0}}.jw-title-clip-poster-play-button{position:absolute;height:100%;width:100%;z-index:20;background-size:60px;background-position:center 45%;background-repeat:no-repeat;cursor:pointer}@media(max-width:992px)and (min-width:768px){.jw-title-clip-poster-play-button--backdrop{background-position:center 25%}}@media(max-width:768px)and (min-width:480px){.jw-title-clip-poster-play-button--backdrop{background-position:center 25%}}@media(max-width:480px){.jw-title-clip-poster-play-button--backdrop{background-position:center 50%}}
# .picture-comp[data-v-6c068c3e],.picture-comp__img[data-v-6c068c3e]{width:100%;max-height:none}.picture-comp__img[data-v-6c068c3e]{display:inline-block}
# .jw-info-box{width:100%;padding:15px 15px 0;background:var(--ion-background-color);border-top:1px solid var(--ion-background-color);position:relative;z-index:0;min-height:800px;margin:-75px auto 0;max-width:1170px}.jw-info-box--trailer-playing{margin-top:0}.jw-info-box__container{display:grid;grid-template-columns:1fr minmax(0,2fr);margin-left:-15px;margin-right:-15px}.jw-info-box__container-content,.jw-info-box__container-sidebar{padding:0 15px}@media(max-width:767px){.jw-info-box__container{grid-template-columns:minmax(0,1fr)}.jw-info-box__container-sidebar{display:none}}@media(min-width:768px){.jw-info-box{padding:25px 25px 0}[dir=ltr] .jw-info-box{border-top-right-radius:16px}[dir=ltr] .jw-info-box,[dir=rtl] .jw-info-box{border-top-left-radius:16px}[dir=rtl] .jw-info-box{border-top-right-radius:16px}}@media(max-width:767px){.jw-info-box{margin-top:0}}.jw-info-box--no-card{border-top:1px solid var(--ion-background-color)}
# .title-sidebar__quick-action-bar{background:#1c252f;margin-bottom:8px}[dir=ltr] .title-sidebar__quick-action-bar{border-bottom-left-radius:4px}[dir=ltr] .title-sidebar__quick-action-bar,[dir=rtl] .title-sidebar__quick-action-bar{border-bottom-right-radius:4px}[dir=rtl] .title-sidebar__quick-action-bar{border-bottom-left-radius:4px}
# .title-poster{position:relative;display:flex;overflow:hidden;padding-top:142.1686747%;background:#0a151f;transition:opacity .1s ease;border-radius:5px;z-index:0}.title-poster:active:not(.title-poster--no-click){opacity:.5}.title-poster--no-poster{display:flex;align-items:center;justify-content:center;text-align:center}.title-poster--no-poster,.title-poster__image{width:100%;height:100%;position:absolute;top:0}.title-poster__image{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;pointer-events:none;border-radius:5px}.title-poster__badge{color:var(--ion-color-light-shade);font-size:12px;border-radius:2px;position:absolute;bottom:8px;z-index:0;text-align:end;background-color:#060d17;padding:1px 5px}[dir=ltr] .title-poster__badge{right:8px}[dir=rtl] .title-poster__badge{left:8px}.title-poster__badge__new{padding:1px 5px;font-size:12px;color:#fff;background:#a30000;position:absolute;bottom:27px}[dir=ltr] .title-poster__badge__new{right:12px}[dir=rtl] .title-poster__badge__new{left:12px}.title-poster__badge__with-provider{bottom:41px}[dir=ltr] .title-poster__badge__with-provider{right:5px}[dir=rtl] .title-poster__badge__with-provider{left:5px}.title-poster__provider{border-radius:0;position:absolute;bottom:10px;z-index:0;text-align:end;opacity:.8;display:flex}[dir=ltr] .title-poster__provider{right:5px}[dir=rtl] .title-poster__provider{left:5px}.title-poster__provider__number{color:#fff;font-weight:700;background-color:#797a7b;padding-top:2px;-webkit-margin-start:5px;margin-inline-start:5px;height:25px;width:25px;border-radius:5px;text-align:center}.title-poster__provider img{-webkit-margin-end:0!important;margin-inline-end:0!important}.title-poster__button{transform:translateY(600px);width:2500px}.title-poster--small-radius{border-radius:2px}[dir=ltr] .title-poster--no-radius-top{border-top-left-radius:0}[dir=ltr] .title-poster--no-radius-top,[dir=rtl] .title-poster--no-radius-top{border-top-right-radius:0}[dir=rtl] .title-poster--no-radius-top{border-top-left-radius:0}[dir=ltr] .title-poster--no-radius-right{border-top-right-radius:0}[dir=rtl] .title-poster--no-radius-right{border-top-left-radius:0}[dir=ltr] .title-poster--no-radius-right{border-bottom-right-radius:0}[dir=ltr] .title-poster--no-radius-bottom,[dir=rtl] .title-poster--no-radius-right{border-bottom-left-radius:0}[dir=ltr] .title-poster--no-radius-bottom,[dir=rtl] .title-poster--no-radius-bottom{border-bottom-right-radius:0}[dir=rtl] .title-poster--no-radius-bottom{border-bottom-left-radius:0}[dir=ltr] .title-poster--no-radius-left{border-top-left-radius:0}[dir=rtl] .title-poster--no-radius-left{border-top-right-radius:0}[dir=ltr] .title-poster--no-radius-left{border-bottom-left-radius:0}[dir=rtl] .title-poster--no-radius-left{border-bottom-right-radius:0}html.ios .title-poster:active{opacity:unset}
# .quick-action-bar--border-top{border-top:1px solid #10161d}.quick-action-bar--border-bottom{border-bottom:1px solid #10161d}.quick-action-bar__group{display:flex;justify-content:space-between}.quick-action-bar__group .quick-action-bar__button{display:flex;flex-direction:column;justify-content:center}.quick-action-bar__group .quick-action-bar__button.basic-button{height:100%}.quick-action-bar__group .quick-action-bar__button.basic-button__content{padding-bottom:10px}.quick-action-bar__group .quick-action-bar__button.basic-button:hover{background-color:transparent}.quick-action-bar__group .quick-action-bar__button.basic-button:active:not(quick-action-bar__button--selected){background-color:#383d47}.quick-action-bar__group .quick-action-bar__button.basic-button:active.quick-action-bar__button--selected{background-color:rgba(251,197,0,.1)}.quick-action-bar__group .quick-action-bar__button .button-description{font-size:13px;font-weight:400;height:28px;letter-spacing:.4px;line-height:15px;margin-top:4px;white-space:nowrap}.quick-action-bar__group .quick-action-bar__button svg{margin:15px auto 5px;display:block}.quick-action-bar--full-width .quick-action-bar__group{margin-left:-15px;margin-right:-15px}
# .title-info{display:block}.title-info.hidden-xs.hidden-sm hr{margin-left:10px;margin-right:10px}.title-info hr:last-child{margin-top:15px}.title-info .detail-infos{display:flex}.title-info .detail-infos:not(:last-child){margin-bottom:6px}.title-info .detail-infos__subheading{max-width:120px;min-width:120px;float:left;overflow:hidden;text-overflow:ellipsis;-webkit-margin-before:0;margin-block-start:0}.title-info .detail-infos__value{display:table-cell;color:#8a8d98}.title-info .detail-infos__value a:hover{cursor:pointer}
# .jw-scoring-listing{display:flex;align-items:center;gap:10px;flex-shrink:0}.jw-scoring-listing__rating{display:inline-flex;align-items:center;height:20px}.jw-scoring-listing__rating img{width:16px;-webkit-margin-end:3px;margin-inline-end:3px;vertical-align:sub}.jw-scoring-listing__rating--no-link{color:inherit!important;pointer-events:none}.jw-scoring-listing__rating a{display:inline-flex;align-items:center;white-space:nowrap}.jw-scoring-listing__rating a img{-webkit-margin-end:6px;margin-inline-end:6px}@media(max-width:380px){.jw-scoring-listing__rating{font-size:13px}.jw-scoring-listing__rating--img{-webkit-margin-end:1px;margin-inline-end:1px}}
# .title-credit-name[data-v-0712fe68]{cursor:pointer}
# .title-block__container{min-height:40px;display:flex;flex-direction:row;justify-content:space-between;align-items:center}.title-block__share-button{align-self:flex-start;color:var(--ion-color-secondary);position:relative;width:108px}.title-block h1{display:inline-block;margin:0;font-size:28px;color:#fff}.title-block .text-muted,.title-block h2{font-size:20px;color:#8a8d98;text-shadow:0 1px 0 #000}.title-block h3{font-size:19px;font-weight:100;margin-bottom:15px;margin-top:0}
# .share-button{position:absolute;display:flex;flex-direction:column;cursor:pointer}[dir=ltr] .share-button{right:0}[dir=rtl] .share-button{left:0}.share-buttons{min-width:79px;align-self:start;padding-top:.5em}.share-buttons__container{display:flex;flex-direction:row;justify-content:flex-end;font-size:16px}.share-buttons__button{cursor:pointer}.share-buttons__button:not(:first-of-type){-webkit-margin-start:16px;margin-inline-start:16px}
# .monetizations{min-height:124px}.price-comparison__badge{color:var(--ion-color-primary);font-weight:700;font-size:9px;text-transform:uppercase;display:inline-block}.price-comparison__badge--bluray{color:#78a6b8;text-transform:none}.price-comparison__badge--dvd{color:#8c8c8c}.price-comparison__grid__row{display:flex;border-bottom:1px solid #10161d}.price-comparison__promoted__container .price-comparison__grid__row{border-bottom-width:0!important}.price-comparison__grid__row__holder{white-space:nowrap;-webkit-overflow-scrolling:touch;overflow:-moz-scrollbars-horizontal;overflow-x:auto;overflow-y:hidden;position:relative;min-height:72px;padding:10px 0;display:flex;align-items:center}.price-comparison__grid__row__holder__notify{display:flex;align-items:center;width:100%}.price-comparison__grid__row__holder__notify--icon{-webkit-margin-end:8px;margin-inline-end:8px}.price-comparison__grid__row__holder__notify--message{margin-top:-14px}.price-comparison__grid__row__holder__notify--message svg{margin-right:8px}.price-comparison__grid__row__holder__notify--message p{line-break:normal;margin-top:0;margin-bottom:8px;line-height:1.6em}.price-comparison__grid__row__holder--no-offer{display:flex;align-items:center;white-space:normal;justify-content:center;margin-top:25px}.price-comparison__grid__row__holder::-webkit-scrollbar{display:none}.price-comparison__grid__row__icon{width:50px;height:50px;margin-bottom:3px;max-width:unset}.price-comparison__grid__row__price{margin-bottom:0;text-align:center;text-decoration:none;color:#d5d5d5;font-size:13px}.price-comparison__grid__row__price span{display:inline-block}.price-comparison__grid__row__price--discounted{line-height:.9;margin-top:-3px}.price-comparison__grid__row__price--new--low{background-color:#1c252f}.price-comparison__grid__row__price--new--medium{background-color:#dd7e00}.price-comparison__grid__row__price--new--high{background-color:#a30000}.price-comparison__grid__row__price--old{text-decoration:line-through;font-size:10px;opacity:.7}.price-comparison__grid__row__price--aggregated{text-transform:none;font-weight:400}.price-comparison__grid__row__title{display:flex;flex-shrink:0;text-align:center;text-transform:uppercase;white-space:nowrap;overflow:hidden;font-size:14px;margin-right:8px;min-width:20px}.price-comparison__grid__row__title span{-webkit-writing-mode:vertical-lr;-ms-writing-mode:tb-lr;writing-mode:vertical-lr}[dir=ltr] .price-comparison__grid__row__title span{transform:scale(-1)}.price-comparison__grid__row__title.ios-13-workaround{left:0}.price-comparison__grid__row--stream .price-comparison__grid__row__title{background:#e6e6e6;color:#797a7b}.price-comparison__grid__row--rent .price-comparison__grid__row__title{background:#797a7b;color:#d5d5d5}.price-comparison__grid__row--buy .price-comparison__grid__row__title{background:#1c252f;color:#d5d5d5}.price-comparison__grid__row--trial .price-comparison__grid__row__title{background:#fff;color:#383d47}.price-comparison__grid__row__element{display:inline-block;position:relative;vertical-align:top}.price-comparison__grid__row__element__icon{-webkit-margin-end:8px;margin-inline-end:8px;text-align:center}.price-comparison__grid__row__element__icon--inactive{opacity:.4}.price-comparison__grid__row--bundle{display:none}.price-comparison--abbreviated{display:none;margin-bottom:20px}@media(max-width:480px){.price-comparison--abbreviated{display:block}}.price-comparison--block{position:relative}.price-comparison--inline:after{content:" ";clear:both;display:block;visibility:hidden;height:0}.price-comparison--inline .price-comparison__grid{border-top:none}.price-comparison--inline .price-comparison__grid__row{display:inline-block;width:-webkit-max-content;width:-moz-max-content;width:max-content;border-bottom:none;padding:10px 0;position:relative;-webkit-margin-end:10px;margin-inline-end:10px}.price-comparison--inline .price-comparison__grid__row__holder{padding:0;min-height:69px;margin-top:5px;overflow-x:hidden;overflow-y:hidden}.price- ...
# .provider-icon,.provider-icon img{border-radius:20%}.provider-icon--labelled{overflow:hidden;height:100%;display:flex;justify-content:center;align-items:center;font-size:1.2rem}.provider-icon--labelled.timeline__provider-block__logo{font-size:.7rem}
# .price-comparison__wrapper[data-v-6e134949]{display:flex;align-items:center;padding-left:10px;padding-right:10px;background:#0a151f}.price-comparison__additional-filter[data-v-6e134949]{display:flex;align-items:center;justify-content:flex-start;padding:4px 8px;background:#0a151f}.price-comparison__additional-filter__heading[data-v-6e134949]{color:var(--ion-color-secondary-tint);text-transform:uppercase;font-weight:700;font-size:14px}.country-switcher__wrapper[data-v-6e134949]{display:flex;align-items:center;justify-content:flex-start;-webkit-margin-start:auto;margin-inline-start:auto}.country-switcher__button[data-v-6e134949]{border:1px solid transparent;border-radius:4px;font-size:15px;background-color:var(--ion-color-secondary-shade);color:#fff;padding:5px 10px;cursor:pointer;text-overflow:ellipsis;overflow:hidden;transition:background-color .1s linear}.country-switcher__button[data-v-6e134949]:active{background-color:transparent}.country-switcher__streaming_in[data-v-6e134949]{color:var(--ion-color-secondary-tint);background:#0a151f;font-weight:700;font-size:15px;-webkit-margin-end:8px;margin-inline-end:8px}@media(max-width:1024px){.country-switcher__country_name[data-v-6e134949],.country-switcher__streaming_in[data-v-6e134949]{display:none}}
# .jw-chip-buttons{display:flex;text-align:center}.jw-chip-buttons .jw-chip-button{width:100%;border-inline-end-width:0!important;-webkit-margin-end:0;margin-inline-end:0;margin-bottom:0}.jw-chip-buttons .jw-chip-button:last-child{border-inline-end-width:1px!important}
# .jw-chip-button{white-space:nowrap;border:1px solid transparent;border-radius:4px;background-color:transparent;transition:background-color .1s linear}.jw-chip-button--no-borders{border:0}.jw-chip-button a{display:block;font-weight:400;font-size:15px;padding:5px 10px;color:var(--ion-color-light-shade)!important;text-overflow:ellipsis;overflow:hidden}.jw-chip-button.active{background-color:var(--ion-color-secondary-shade);color:#fff}.jw-chip-button.active a{color:#fff!important}.jw-chip-button:last-child{border-inline-end-width:1px!important;-webkit-margin-end:0;margin-inline-end:0}
# .offer-reporter-button{display:block;clear:both;font-size:13.5px;margin-top:5px}
# .ad-unit[data-v-10e87f51]{display:flex;flex-direction:column;align-items:center}.ad-unit__container[data-v-10e87f51]{overflow:hidden;display:block!important;background-color:#0a151f;margin:auto;text-align:center}.ad-unit__container div iframe[data-v-10e87f51]{vertical-align:middle!important}.ad-unit__removal[data-v-10e87f51]{text-align:center;margin:5px auto auto;min-height:22px}.ad-unit__removal button[data-v-10e87f51]{border:none;background:none;color:var(--ion-color-secondary)!important}.ad-unit--no-margin-top .ad-unit__container[data-v-10e87f51]{margin-top:0}
# .title-credits{margin-bottom:15px;padding-bottom:5px;color:#8a8d98}.title-credits .hidden-horizontal-scrollbar__items{align-items:normal}.title-credits__actor{display:inline-block;-webkit-margin-start:15px;margin-inline-start:15px}.title-credits__actor:first-child{-webkit-margin-start:0;margin-inline-start:0}.platform-android .title-credits__actor,.title-credits__actor .platform-ios{-webkit-margin-start:15px!important;margin-inline-start:15px!important}.title-credits__actor--name{display:block;width:130px;text-overflow:ellipsis;overflow:hidden}.title-credits__actor--role{white-space:nowrap;max-width:130px}.title-credits__actor--role,.title-credits__actor--role--name{overflow:hidden;text-overflow:ellipsis}
# .hidden-horizontal-scrollbar{overflow:hidden;display:flex;position:relative}.hidden-horizontal-scrollbar__items{overflow-x:auto;scrollbar-width:none;-webkit-overflow-scrolling:touch;-ms-overflow-style:-ms-autohiding-scrollbar;position:relative;flex-wrap:nowrap;display:flex;align-items:center}.hidden-horizontal-scrollbar__items::-webkit-scrollbar{display:none}.hidden-horizontal-scrollbar__items>*{flex:0 0 auto}.hidden-horizontal-scrollbar__items.shift-scrollbar{-webkit-margin-start:-46px;margin-inline-start:-46px}@media(max-width:380px){.hidden-horizontal-scrollbar__items.shift-scrollbar{-webkit-margin-start:-26px;margin-inline-start:-26px}}.hidden-horizontal-scrollbar__nav{background:rgba(6,13,23,.8);cursor:pointer;position:absolute;top:0;height:100%;width:40px;display:none;font-size:25px;justify-content:center;align-items:center;z-index:8}[dir=ltr] .hidden-horizontal-scrollbar__nav--end{right:0}[dir=ltr] .hidden-horizontal-scrollbar__nav--start,[dir=rtl] .hidden-horizontal-scrollbar__nav--end{left:0}[dir=rtl] .hidden-horizontal-scrollbar__nav--start{right:0}@media(pointer:fine){.hidden-horizontal-scrollbar:hover .hidden-horizontal-scrollbar__nav{display:flex!important}}@media(max-width:767px){.hidden-horizontal-scrollbar{margin-left:-15px;margin-right:-15px}.hidden-horizontal-scrollbar__items{padding-left:15px;padding-right:15px}}
# .text-wrap-pre-line[data-v-ef8fcdca]{white-space:pre-wrap}ul[data-v-ef8fcdca]{color:#8a8d98;font-size:16px}@media(max-width:480px){ul[data-v-ef8fcdca]{font-size:14px}}
# .horizontal-title-list{--margin-top:10px;margin-top:var(--margin-top)}.horizontal-title-list__item{margin:0 5px;position:relative}.horizontal-title-list__item__caption{margin:5px;overflow:hidden;max-width:155px;white-space:nowrap;text-overflow:ellipsis}.horizontal-title-list__item:first-child{-webkit-margin-start:0;margin-inline-start:0}.horizontal-title-list .title-poster{width:190px}@media(max-width:767px){.horizontal-title-list .title-poster{width:180px}}@media(max-width:380px){.horizontal-title-list .title-poster{width:156px}}.timeline .horizontal-title-list{-webkit-margin-start:-35px;margin-inline-start:-35px}.timeline .horizontal-title-list .hidden-horizontal-scrollbar__items{padding-left:35px;padding-right:35px}@media(max-width:767px){.timeline .horizontal-title-list .hidden-horizontal-scrollbar__items{-webkit-padding-start:50px;padding-inline-start:50px}}
# .title-poster-ribbon[data-v-eba9c096]{position:absolute;z-index:1;font-size:48px;padding:0 8px 8px;top:-8px;color:#fff;opacity:.3}[dir=ltr] .title-poster-ribbon[data-v-eba9c096]{left:0}[dir=rtl] .title-poster-ribbon[data-v-eba9c096]{right:0}.title-poster-ribbon[data-v-eba9c096]:hover{opacity:.7;cursor:pointer}.title-poster-ribbon--active[data-v-eba9c096]{opacity:1;color:var(--ion-color-primary)}.title-poster-ribbon--active[data-v-eba9c096]:hover{opacity:.7}
# .jw-app-footer[data-v-71391f3d]{padding-top:6em;margin-bottom:1em}@media(max-width:1050px){.jw-app-footer[data-v-71391f3d]{padding-left:25px!important;padding-right:25px!important}}.jw-app-footer h5[data-v-71391f3d]{font-size:100%}.jw-app-footer h5 a[data-v-71391f3d]{color:#d5d5d5}.jw-app-footer__link[data-v-71391f3d]{margin-bottom:.5em}.jw-app-footer__heading[data-v-71391f3d]{width:100%;display:flex;justify-content:space-between;align-items:baseline}.jw-app-footer__heading-left[data-v-71391f3d]{font-size:18px}.jw-app-footer__heading-left-brand[data-v-71391f3d]{color:#fff}.jw-app-footer__heading-left-separator[data-v-71391f3d]{color:#383d47}.jw-app-footer .footer-links[data-v-71391f3d]{display:grid;gap:16px;grid-template-columns:repeat(auto-fit,minmax(180px,1fr))}
# .mobile-banner{display:none;height:79px;border-top:1px solid #10161d;background-color:var(--ion-background-color);position:fixed;bottom:0;width:100%;z-index:10}@media(max-width:599px){.mobile-banner.show-banner{display:block}}@media(min-width:600px){.mobile-banner.show-banner{display:block}}@media(min-width:1000px){.mobile-banner.show-banner{display:none}}.mobile-banner__container{-webkit-padding-end:50px;padding-inline-end:50px;text-align:center;width:100%;height:100%}.mobile-banner__background{background-size:contain;background-repeat:no-repeat;background-position-x:center;width:100%;height:100%}@media(min-width:600px){.mobile-banner__background{background-position-x:53%}}.mobile-banner__close{position:absolute;top:0}[dir=ltr] .mobile-banner__close{right:0}[dir=rtl] .mobile-banner__close{left:0}.mobile-banner__close:hover{cursor:pointer}.mobile-banner__close__area{position:relative;top:10px;display:inline-block}[dir=ltr] .mobile-banner__close__area{right:10px}[dir=rtl] .mobile-banner__close__area{left:10px}</style></head><body><div data-server-rendered="true" id="app"><!-- --><!-- --><div class="navbar container-fluid container-max-width"><div style="display: flex; width: 100%"><div class="navbar__logo"><a class="router-link-active" href="/"><div class="navbar__logo-link"><picture><source media="(min-width: 0px)" srcset="appassets/img/logo/JustWatch-logo-large.webp" type="image/webp"/><img alt="JustWatch" src="appassets/img/logo/JustWatch-logo-large.png"/></picture><!-- --></div></a></div><div class="navbar__wrapper"><a class="navbar__button__link landing-hide router-link-active" href="/"><span class="navbar__button__link__item">홈</span></a><a class="navbar__button__link" href="/kr/%EC%B5%9C%EC%8B%A0"><span class="navbar__button__link__item">New</span></a><a class="navbar__button__link" href="/kr"><span class="navbar__button__link__item">인기</span></a><span class="navbar__button navbar__button--watchlist landing-hide"><a class="navbar__button__link" href="/kr/%EC%8B%9C%EC%B2%AD%EB%AA%A9%EB%A1%9D"><span class="navbar__button__link__item"> 시청 목록 </span><svg aria-hidden="true" class="navbar__button__icon bookmark svg-inline--fa fa-bookmark fa-w-12" data-icon="bookmark" data-prefix="fas" focusable="false" role="img" viewbox="0 0 384 512" xmlns="http://www.w3.org/2000/svg"><path d="M0 512V48C0 21.49 21.49 0 48 0h288c26.51 0 48 21.49 48 48v464L192 400 0 512z" fill="currentColor"></path></svg></a></span><div class="navbar__search"><div class="search-suggester search-suggester--web"><div class="search-suggester__blocking"><div class="searchbar-input search-suggester__blocking__input"></div></div><!-- --><!-- --></div><!-- --></div><div class="navbar__extra"><div class="navbar__button" data-v-7fdc0144=""><div class="not-logged-in" data-v-7fdc0144=""><button class="basic-button not-logged-in__button tertiary md rounded" data-v-7fdc0144="" type="button"><div class="basic-button__content"><span data-v-7fdc0144="">로그인</span></div></button><svg aria-hidden="true" class="not-logged-in__icon svg-inline--fa fa-user-cog fa-w-20" data-icon="user-cog" data-prefix="fas" data-v-7fdc0144="" focusable="false" role="img" viewbox="0 0 640 512" xmlns="http://www.w3.org/2000/svg"><path d="M610.5 373.3c2.6-14.1 2.6-28.5 0-42.6l25.8-14.9c3-1.7 4.3-5.2 3.3-8.5-6.7-21.6-18.2-41.2-33.2-57.4-2.3-2.5-6-3.1-9-1.4l-25.8 14.9c-10.9-9.3-23.4-16.5-36.9-21.3v-29.8c0-3.4-2.4-6.4-5.7-7.1-22.3-5-45-4.8-66.2 0-3.3.7-5.7 3.7-5.7 7.1v29.8c-13.5 4.8-26 12-36.9 21.3l-25.8-14.9c-2.9-1.7-6.7-1.1-9 1.4-15 16.2-26.5 35.8-33.2 57.4-1 3.3.4 6.8 3.3 8.5l25.8 14.9c-2.6 14.1-2.6 28.5 0 42.6l-25.8 14.9c-3 1.7-4.3 5.2-3.3 8.5 6.7 21.6 18.2 41.1 33.2 57.4 2.3 2.5 6 3.1 9 1.4l25.8-14.9c10.9 9.3 23.4 16.5 36.9 21.3v29.8c0 3.4 2.4 6.4 5.7 7.1 22.3 5 45 4.8 66.2 0 3.3-.7 5.7-3.7 5.7-7.1v-29.8c13.5-4.8 26-12 36.9-21.3l25.8 14.9c2.9 1.7 6.7 1.1 9-1.4 15-16.2 26.5-35.8 33.2-57.4 1-3.3-.4-6.8-3.3-8.5l-25.8-14.9zM496 400.5c-26.8 0-48.5-21.8-48.5-48.5s21.8-48.5 48.5-48.5 48.5 21.8 48.5 48.5-21.7 ...
# <script>
# 			window.DNS_PREFETCH=[{"rel":"dns-prefetch","href":"https://www.googletagmanager.com/"},{"rel":"dns-prefetch","href":"https://ib.adnxs.com"}];
# 			window.HTTP_PRECONNECT=[{"rel":"preconnect","crossorigin":"use-credentials","href":"https://images.justwatch.com"}];
# 			window.JW_CONFIG={"API":"https://apis.justwatch.com/content","APPSFLYER_DEVKEY":"gSUwxKVg6BMrcBDc4DemBP","ASSETS_URL":"https://www.justwatch.com/static/compile_jw/assets","BRAZE_BASE_URL":"sdk.iad-05.braze.com","BRAZE_WEB_API_KEY":"1aad19f0-6f9f-4fd5-9a05-9ca5499795f9","CHECKIP_URL":"https://info.justwatch.com ","CLICK_URL":"https://click.justwatch.com","DISCOVERY_URL":"https://apis.justwatch.com/discovery","DOMAIN":"justwatch.com","EVENT_URL":"https://apis.justwatch.com/event","EXPERIMENT_CONFIG_URL":"https://apis.justwatch.com/configuration/experiments","FACEBOOK_APP_ID":"794243977319785","FEEDBACK_URL":"https://apis.justwatch.com/feedback","FIREBASE_API_KEY":"AIzaSyDv6JIzdDvbTBS-JWdR4Kl22UvgWGAyuo8","FIREBASE_APP_ID":"1:413470318987:web:28b910bbf217d7d5034f8e","FIREBASE_AUTH_DOMAIN":"accounts.justwatch.com","FIREBASE_MESSAGING_SENDER_ID":"413470318987","FIREBASE_PROJECT_ID":"justwatch-apps-beta","FIREBASE_STORAGE_BUCKET":"justwatch-apps-beta.appspot.com","GOOGLE_CLIENT_ID":"532718895899-fhbuhnd9nsrae0ivadejq35vsr2sgr0l.apps.googleusercontent.com","GOOGLE_MAPS_API_KEY":"AIzaSyBVU86Zuf3v_6W8dnnV9BRKe_YSBXroqCA","GRAPHQL_URL":"https://apis.justwatch.com/graphql","IDENTITY_URL":"https://apis.justwatch.com/identity","ID_URL":"https://i.tw.cx","IMAGESCALER_FAST_URL":"https://www.justwatch.com/images","IMAGESCALER_URL":"https://images.justwatch.com","ITUNES_APP_ID":"979227482","NOTIFICATION_URL":"https://apis.justwatch.com/notification","PLOT_RECOMMENDER_URL":"https://apis.justwatch.com/plotpoint","PULL_URL":"https://apis.justwatch.com/push","PUSH_API_URL":"https://p.tw.cx","REVENUE_CAT_API_URL":"https://api.revenuecat.com/v1/subscribers","REVENUE_CAT_PUBLIC_KEY":"sijZLciaBRrTwuIAeBkAqzQNtMNQaXqV","SENTRY_DSN":"https://ad6b9c4b3a3f4e998e38c3c7ed92574f@sentry.justwatch.com/4","SENTRY_DSN_MOBILE":"https://cfd5bfa2ae754a9ab298f2c534690151@sentry.justwatch.com/6","SENTRY_DSN_SSR_CLIENT":"https://88c648a39a6b484ca1a6d7656076e655@sentry.justwatch.com/16","SNOWPLOW_COLLECTOR_ENDPOINT":"www.justwatch.com","USER_URL":"https://userapi.justwatch.com","WRITE_URL":"https://apis.justwatch.com/personalization"};
# 			window.IMG_POSTER_LOAD_COUNT=4;
# 			window.IMG_PROVIDERS_BAR_LOAD_COUNT=7;
# 			window.IMG_PROVIDERS_BUY_BOX_COUNT=6;
# 			window.IMG_NEW_TIMELINE_ROWS=1;
# 			window.NEW_TIMELINE_BUCKETS_LIMIT=4;
# 			window.NEW_TIMELINE_TITLES_PER_BUCKET_LIMIT=10;
# 		</script><script defer="" src="/appassets/5607a911/js/runtime.01f1e33f.js"></script><script defer="" src="/appassets/5607a911/js/detail.1127f8a3.js"></script><script defer="" src="/appassets/5607a911/js/detail~sports.14ebad93.js"></script><script defer="" src="/appassets/5607a911/js/backdrop-trailer.f897f6dc.js"></script><script defer="" src="/appassets/5607a911/js/detail~home-global~home-onboarded~home-taste-onboarding~leavingsoon~lp-plot-recommender~mobile-searc~ce13aaf9.840357cd.js"></script><script defer="" src="/appassets/5607a911/js/detail~leavingsoon~lp-plot-recommender~sports~title-list-card~title-list-row.9f1dd5f6.js"></script><script defer="" src="/appassets/5607a911/js/chunk-16b28f65.a3b3a697.js"></script><script defer="" src="/appassets/5607a911/js/chunk-2d0b6a9a.5b1a5925.js"></script><script defer="" src="/appassets/5607a911/js/detail~home-onboarded~mobile-search~mobile-search-person~new~sports~timeline-fallback-titles.3ac94c74.js"></script><script defer="" src="/appassets/5607a911/js/default-footer.af791c76.js"></script><script defer="" src="/appassets/5607a911/js/low-priority-components.dbc35031.js"></script><script defer="" src="/appassets/5607a911/js/mobile-banner.dbd10713.js"></script><script defer="" src="/appassets/5607a911/js/npm.vue.9dc5f794.js"></script><script defer="" src="/appassets/5607a911/js/npm.sentry.02cef871.js"></script><script defer="" src="/appassets/5607a911/js/npm.graphql.46f01390.js"></script><script defer="" src="/appassets/5607a911/js/npm.stream-http.6257cefc.js"></script><script defer="" src="/appassets/5607a911/js/npm.firebase.82980b49.js"></script><script defer="" src="/appassets/5607a911/js/npm.fortawesome.280e5340.js"></script><script defer="" src="/appassets/5607a911/js/npm.apollo-client.5c307da8.js"></script><script defer="" src="/appassets/5607a911/js/npm.localforage.bd55e5d5.js"></script><script defer="" src="/appassets/5607a911/js/npm.vue-router.294487ee.js"></script><script defer="" src="/appassets/5607a911/js/app.1a7ed743.js"></script></body><script async="" src="/appassets/js/lazysizes.min.js"></script></html>
